# %%
import pandas as pd

# %%
df = pd.DataFrame(columns={"name","image_link","src","price"})
df
# Out:
# Empty DataFrame
# Columns: [price, src, name, image_link]
# Index: []

# %%
df.append({"price":54,"src":"adsfasdf","name":"asdfsdf","image_link":"hello"},ignore_index=True)
# Out:
# C:\Users\shashank singh\AppData\Local\Temp\ipykernel_6220\2535991709.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({"price":54,"src":"adsfasdf","name":"asdfsdf","image_link":"hello"},ignore_index=True)
#   price       src     name image_link
# 0    54  adsfasdf  asdfsdf      hello

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                                  name  \
# 0                   Microgreens Growing Kit Pack of 2
# 1   Homemade Desi Cow Dung Cake(30 Pack-Free Deliv...
# 2     Plant Care Kit ( Pack of 4) Natural and Organic
# 3                       Little Gardeners Kit for Kids
# 4                   Bhendi/Okra Non-Hybrid (80 Seeds)
# 5                          Palak/Spinach (400+ Seeds)
# 6                       White Bitter Gourd (30 Seeds)
# 7                      Tomato Non Hybrid (400+ Seeds)
# 8                          Palak/Spinach (400+ Seeds)
# 9             Amaranth Green(Thotakura) (1400+ Seeds)
# 10                             Coriander (300+ Seeds)
# 11                           Chukka Kura (250+ Seeds)
# 12             Microgreen Amaranthus Seeds (100 Grms)
# 13                  Microgreen Methi Seeds (100 Grms)
# 14                Microgreen Mustard Seeds (100 Grms)
# 15                  Microgreen Palak Seeds (100 Grms)
# ...

# %%
df2 = pd.read_csv('native.csv')
df2.head(70)
# Out:
#                                             name  \
# 0                     Palak/Spinach (400+ Seeds)
# 1                         Coriander (300+ Seeds)
# 2                       Chukka Kura (250+ Seeds)
# 3              Bhendi/Okra Non-Hybrid (80 Seeds)
# 4              Bhendi/Okra Non-Hybrid (80 Seeds)
# ..                                           ...
# 65  Dolichos Creeper(Theega Chikkudu) (15 Seeds)
# 66                     Cluster Beans (80+ Seeds)
# 67        Yellow Cucumber(Dosakaya) (100+ Seeds)
# 68                         Onion Red (400 Seeds)
# 69          Keera Cucumber Non Hybrid (50 Seeds)
#
#                                            Image_link  \
# 0   https://www.seedbasket.in/image/cache/catalog/...
# 1   https://www.seedbasket.in/image/cache/catalog/...
# 2   https://www.seedbasket.in/image/cache/catalog/...
# 3   https://www.seedbasket.in/image/cache/catalog/...
# 4   https://www.seedbasket.in/image/cache/catalog/...
# ...

# %%
# Out:
#                                                  name  \
# 0                   Microgreens Growing Kit Pack of 2
# 1   Homemade Desi Cow Dung Cake(30 Pack-Free Deliv...
# 2     Plant Care Kit ( Pack of 4) Natural and Organic
# 3                       Little Gardeners Kit for Kids
# 4                   Bhendi/Okra Non-Hybrid (80 Seeds)
# 5                          Palak/Spinach (400+ Seeds)
# 6                       White Bitter Gourd (30 Seeds)
# 7                      Tomato Non Hybrid (400+ Seeds)
# 8                          Palak/Spinach (400+ Seeds)
# 9             Amaranth Green(Thotakura) (1400+ Seeds)
# 10                             Coriander (300+ Seeds)
# 11                           Chukka Kura (250+ Seeds)
# 12             Microgreen Amaranthus Seeds (100 Grms)
# 13                  Microgreen Methi Seeds (100 Grms)
# 14                Microgreen Mustard Seeds (100 Grms)
# 15                  Microgreen Palak Seeds (100 Grms)
# ...
